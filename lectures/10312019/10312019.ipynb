# %% [markdown]
# From last lecture we have 2 sites, one nonbinding and one binding where we take features over 240 sites.
#
#
# <img src="10312019_01.png">
# Altman;s Feature program: to predict binding sites.
# build classifier to find new protein binding sites. build a grid over the protein and figute out
# the grid spacing, sufficiently finely spaced. grid 1.5A usually. at each point in protein build a feature vector
# trained on past binding sites. Most of these will look like nonsites. Can use some supervised method, cant do DL cause
# not enough data. That is how you identify 3d motifs. he does this in his lab in 1995. Steve bagly.
#
# <img src="10312019_02.png">
# pocket feature: for comparing pockets in proteins. The pockets were too big to have spheres envelop them using
#     feature definition from above. Put points around pockets as features. Teh system altman built callef feature.
#     Put feature vectors around the pocket. Did not elaborate. He had 2 pockets, pocket1 has 5 feature vectors,
#     pocket 2 has 6 feature vectors. HE built algo that said are these 5 in pocket 1 more similar than 2 tahn by
#     chance. By chance you use the nonsite binding pockets or you pick from all your dara find a distribution.
#     Build several feature vectora around the pocket. Are teh 6 on left
#     more similar to the ones on right than by chance? If D1, D2, D3 bind to pocket 1 and pocket 2 is similar
#     it is a good estimate these drugs will bind to pocket 2 also. If pocket1 has list of drugs it binds, If this is drugs then this
#     is one way to do drug repurposing. find new uses for existing drugs.
# <img src="10312019_03.png">
# repurposing. he wwrote paper last year where thers is a binding pocket in tublin that looks a lot like the estrodgen
# receptor. this site is also bound to by chemotherupatic agents. one way to stop cancer is to stop ability to make
# mircotubles or prevent attachemtn to this part of the tublin protein. There are anti estrogens which bind the estrogen
# receptor. tamoxifin for breast cancer turns otu it also binds tubulin.
# <img src="10312019_04.png">
#
# <img src="10312019_05.png">
# finding the similarities give the offtarget effects. when you find a similar protein small molecule will bind to
# or a similar binding site. How to quantify similarity? The features have different distirbutions. The simimlairy is
# not euclidean distance. You use the nonsites , 2-3 angstroms margin and then look for a big difference before saying
# there is a separation between binding and nonbinding site. Each one of teh 240 features is renormaliezed. Pocket feature is
# final example of a 3d motif. What are the other 2? Contrast these for pros and cons. we are describing a 3d motif as a
# vectof of 240 numbers. There were 3, 1) feature, 2) pocket feature, 3) fragfeature.
#
# <img src="10312019_06.png">
# What is the difference between pocket feature
# and frag feature? Why is one better than the other? Frag feature, you cant find pockets similar to a pocket with
# your feature vectors. Want to bind drugs to this pocket but not similar to any known bindings. The trick is to associate 2 or 3 of these
# features together to anotehr binding site. Because there are interdependencies. YOu find that the 2 features together
# or the 2 sites together bind to a certain shape and the 3 together which define a fragment binds to that circualr structure.
# <img src="10312019_07.png">
# So now I have a hypothessis that if I can find a small molecule that has those 2 shapes and are connected somehow
# that molecule can bind to this site. W/O using similarities.
# <img src="10312019_08.png">
# the reason the 3d shells work so well is they wanted to dial up teh sensitiveity wo worrying about specificty.
# <img src="10312019_09.png">

# %% [markdown]
# <img src="10312019_10.png">
# <h6>Protein Structure Prediction</h6>
# how to fold long AA sequence? One way is to use physics and energy prediction. but there are drawbacks to this. We
# dont know how this really works except it happens quickly and we cant model this accurately. In PDB we have 150k structures.
# Before 1994 people predict structure based on linear sequence but was never replicated. they think they were getting
# good perormance which couldnt be replicated because of data leakage. They created CASP, 3 groups of people. 1) experimentalists
# who have 3d structure, they would hold off publication for 3-6 months and 2) predictors would try to predict what the structure
# was and 3) assessors evaluated predicdtions. did they get teh alpha helixes and beta strands correct, what was rmsd? between predicted
# and verified crystal structure?
# <img src="10312019_11.png">
# example with one seauecne from PDb and one target sequence. ALignmant has GLVM and deletion and insertion.
# <img src="10312019_11a.png">
# <h6>Categories in CASP</h6>
# homology modeling: if a sequence is 30-35% similar to another sequence in the PDB database w/150k entries then you
# are doing homology modeling. steps for homology modeling:
#
# <p></p>
# 1) find sequence alignment using project 1 alignment.
# <p></p>
# 2) align the c-alpha between sequences, where the columns match those places have a c alpha at same place
# <p></p>
# 3) columns with different AA ssame c-alpha but change the side chain. choose most likely side chain from database.
# <p></p>
# 4) the gap and insertion are problems.
# <img src="10312019_12.png">
# for the gap you have 3 positions in the pdb vs 2 in the gap. that is too far so
# you use energy minimizaetion. In the image below we have 2 sequences. The top one is our sequene
# we are trying to find the 3d strcuture for, teh second one is the PDB closest match with the matching
# columns. There are columns with the same AA and columns wiht different AA. With same AA we use the same
# structure in teh DB, align the c-alpha to same 3d location and use the same side chains. For different AA you have
# c-alpha in same place but you ahve to change the side chain. Take the DB side chain and replace with side chain from the
# AA of your sequence. If different side chain, when we are replacing, choose the most likely confirmation side chain from a database.
# L-V is different and needs side chain picking, you put L in teh most likely conformation position and put c-alpha in same place as V c-alpha.
# <img src="10312019_12a.png">
# <img src="10312019_13.png">
# use energy minimization for inertion also. if the distances are small enough then use enregy minimization. as
# the distances get bigger you get worse and worse results. Minimize Utotal. (has many components)
# <img src="10312019_14.png">
# if seq is 80% or more same then result is same as if you solved experimentally.
# <img src="10312019_15.png">

# %% [markdown]
# <img src="10312019_16.png">
# 2 casps ago they were predicting function using feature and pocket feature to proteins where they knew function.
# for low levels of siilarity can apply 3d motif finding on the new predicted structures.
# <img src="10312019_17.png">
# second big category for casp is fold recognition. after millions of years evolution 2 sequences are less than 15% similar.
# but when you solve 3d structure they are the same! fold recogniotion is designed to find distant sequences which adopt the same fold.
# build library of backbone structures, alpha helix and betal strands, then do AA>
# <img src="10312019_18.png">
# start w AA sequence, want 3d structure. first try homology modeling. Can do well w homology but need to get ~20%
# similar w homology for minimum motif finding. If cant get this then do fold prediction before abinitio. fold prediction you
# find 3d structure same but w different sequence. 2 methods.
# <img src="10312019_19.png">

# %% [markdown]
# <p> FR by dynamic programming.</p>
# 1) map each AA pos in fold to environmental descriptor
# <img src="10312019_20.png">
# what is descriptor;
#
# <img src="10312019_21.png">
# <img src="10312019_22.png">
# <img src="10312019_23.png">
# <img src="10312019_24.png">
