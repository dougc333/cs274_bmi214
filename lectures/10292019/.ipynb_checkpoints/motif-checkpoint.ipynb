# %%
<img src="motif1.png">
<img src="motif2.png">
TF is example of 1d motif. You can find these motifs from local alignment. 
<img src="motif3.png">
<img src="motif4.png">
<img src="motif5.png">
these numbers are seeing probability of seeing AA per column. column2 set .05 if you see nothing give equal
probability over alphabet of 20aa. This is a scoring matrix for the 1d motif D*EG binding calcium sequecne/motif. 
<img src="motif6.png">
if you want to mess with sensitivity you put epsilon on PSSM where epsilon is some small constant not 0 because
eventually you will see this. Similar to naive bayes trick where for unseen event you give small number and still
have probability add up to 1. 
<img src="motif7.png">
in biology you know the positions are sometimes correlated position 1 and position 4. This isnt good for hmms which 
dont capture any of these relationships beyone the next state. PSSMS are above blosom62 in specifity but cant
capture these position dependent probabilies like between position 1 and 4. 
<img src="motif8.png">
the blosum62 scoring matrix is derived by looking at BLOCKS database. BLOCKS is derived from hits from prosite.  
<img src="motif9.png">
One way to describe a set of consensus sequences is to use a sequence logo. This shows DNA only but you 
can do this for proteins. Advantage: can see where in the sequence the strongest conservation as binding site for Tf. 
    Disadvantage: can be wrong bc it doesnt score indels and the background at 0 is equal probability of each nucleotide
        which we know not to be true from PAM and Blosum62. 
    
<img src="motif10.png">
the height is C(i) of the letters and indicates percent conserved across MSA. 
<img src="motif11.png">
lowest entropuy is when conserved. no change.
the highest possible entropy is when ATCG are all equal probability which is -2. 
<img src="motif12.png">
3d motif. Advantage: detect binding, enzymatic active sites. enzymes are proteins catalyze.  Disadvantage of using sequnece logos to predict binding sites from height of logos is
it doesnt take into account 3d informatiom. In 3d the binding constraints are the red dots binding to the Ca molecule then 
if you linearize this you will never find it bc the loops are all of variable
<img src="motif13.png">
AN enzyme binding site is blue S which sits in pocket and catalyzes reactions. When you see a protein you have to find
teh enzymatic binding site. 
<img src="motif14.png">
3d motifs can give clues to binding and active sites on protein. A Ca2+ binding site sits in a protein with 4 
binding sites to a protein in a pocket. If you flatten out the sequence you get a big gap between the 6 binding sites 
in a linear representation. Bad news is we need a 3d structure and the database of 3d structures is limited; 150k in PDB. 
<img src="motif15.png">
<img src="motif16.png">
serine protease breaks peptide bonds and stable in stomach acid. when you eat steak it breaks down the steak into
AA in digestion pricess. can also use for detergent if make stable at hightemps for protein stains
<img src="motif17.png">
FFF: how to find 3d motif alignment. Sequence alignment, if sequence identity<120% cannot detect functional and structural
    similarities. By chance get random match w/20AA. FFF is a supervised method where the similarity metric is range
    overlap. IF any range of AA(HIS, SER) 2 AA overlap then this is similar and match for MSA. 
<img src="motif18.png">
<img src="motif18a.png">
FFF if you have additional AA then each triangle you have to compare. Disadvantaes: doesnt scale well to 
    higher chains. Vague on how to assign triangle or ranges. 2 ASP, 2 SER, 2 HIS, more than 2 triangles.  so this is 
    2x2x2 combinations, 8 combinations and if any is a hit then yes for serine protease. advanatage: fast,easy for simple 
        configuaitons for small proteins. When is this good for MSA? if you need to search one vs. entire database or match one to existing
        matched set. Easier to compute, we can do that with PDB information.  gives general compare big vs small
        and find me a similarity where there is a single range match between 3d structures. Sometimes good enough. Disadvantage:
            can have FP if 1 range 
<img src="motif18b.png">
FFF Disadvantage; have to read teh biological literature.  This is a supervised classified method. 
<img src="motif19.png">
TESS: template search and superposition. Find one AA you know is important, like HIS. mark all AA within 18A AA of 
    interest. Make ball and get all AA in 18 angsteoms. SUpervised classification. 
<img src="motif20.png">

<img src="motif21.png">
tradeoff between sensitivity and specifity. make box bigger and smaller
<img src="motif22.png">
Steve Bagley
<img src="motif23.png">
<img src="motif24.png">
pick single point which is N in HIS and draw concentric shells. Evaluate all 40 properties in each shell. 
do you sum the atoms? yes. count. For example below shell 4. 40 properties, one maybe charge. Look at every atom
what is charge? +1, .5, Put it in charge feature vector for shell 4. 
<img src="motif25.png">
