# %%
pharmogenetics is the study of genetics influence on drugs. 
<img src="1232019_01.png">
amazing, he can perdcribe drugs. There are things that prevent drug effect. 1) did take drug, 2) if tehre are diseases
present with interfere with drug pathway, 3) eat or ingest something with binds w/small molecule. 4) microbiome the bacdteria in gut
affects can transform small molecules to something less or more effective than the drug you take. 5) dna affecxts drugs
many drugs invented in last 10y so you have no family history, no family history documented on drug interactdions like grandma dies
when she took x. For ADME, absorbtion is affected by proteins! 
<img src="1232019_02.png">
The concentration curve of a drug is shown starting at concentration 0. As long as teh concentration is above the 
minimum level required to be effective, then as is decreases this determines the dosing. This curve is called a PK curve. 

<img src="1232019_03.png">
 There are transporder proteins 
that sit in lumen in your gut which transports AA, sugars, and drugs to cell. Active transporters are ABC, ATP binding
cassette. The active transporters use ATP for energy and can transport against the gradient. There are passive transporters
which dont require energy and bring molecules across membrane. Teh gradient is high concentration to low concentration. 
Diffucion powered by mean free path motion. They did multiple sequence alignment run HMM and figured out these were
all related. They figured out these transporters were all related using HMM/MSA. They differ by specificity which transport
positive charged molecules or negative charged molecules. Even for a single transporter there are variations in the population 
These variations change teh function of the transporter from postitive charge transproter to negative charged transporter. 

<img src="1232019_04.png">
example of higer absorbtion rate, the peak on PK curve is higher. Example later where this really does happen. 
The case of the red curve means take a lower dose but take it more frequently. 
<img src="1232019_05.png">
ADME: metabolism is done by liver. All your blood goes to liver before distribution to rest of body. 
2 parts of metabolism, phase1 enzymes: adds and subtracts O, H,cytochrome450. cytochrome450 is a gene family, discoveed via multiple alignment. 
The share an alignment but they differ in specifity. phase2 enzymes:conjugation enzymes. THey do chemistry on small molecules
    hoping to get rid of the toxic ones which will kill you. A phase2 enzyme might add a methyl group(NH3) a phosphate group (PO4), a
    sulfate group(SO4). The phase2 enzymes do this to make small molecule more soluable so they will be excreted through urine or bowel. Whole
    goal of phase 2 enzymes is to excrete after binding. The Phase1/Phase2 enzymes affect the downward part of the PK curve
    because that determines how fast it is being excreted. Funny, it passes througthe liver first then continues to be excreted. 
    These dosing effects matter because if too high you have increased chance for side effects from drug. 
<img src="1232019_06.png">
<img src="1232019_07.png">
Pharmodynamics. This is what the body will do with the drug. An example is proton pump inhibitor which inhibits the proton 
pump if overactive causes acid stomach. Would move ph of stomcach from 4 to 7. What happens if there are variations in this drug target?

<img src="1232019_08.png">
Changes in AA might bind prilosec more or less tightly. If binds tightly you might not need as much drug and if
opposite loosely you need less of the drug. 
<img src="1232019_09.png">

# %%
This is new level for change in PD. Lower level if you AA binds the drug more tightly to Proton pump. This is one way 
genetic variations in target would change dose of drug. Another way is there is always a pathway which uses network biology

<img src="1232019_10.png">
network effect is if you cant reach disease gene you can reach another gene upstream of it and this affects dose?
<img src="1232019_11.png">
this tricky becayse genetic variations in each of hte upstream genes will affect the disease geene. So in medical school 
you learn what the PK and PD is for each drug!. 
<img src="1232019_12.png">
for patients on 10-15 drugs and there are problems. you spit into cup which goes to microarray then this matches the 200
SNPs they know about and he looks at genotype can comapre vs interatctions and can change dose, timing of dose, or pick 
another drug. $1200.00 for clinic test. 
<img src="1232019_13.png">
Example; codeine. Codeine is a placebo but when it gets to your liver there is cytochrome450 cytochrome CYP2D6 which
makes codeine more effective by. .. Called 2D6 because someone made a tree a multiple sequence alignment of all the cytochromes. 
The MSA produces a tree and you can label the leaves. 
<img src="1232019_14.png">
The tree from 2D6 means 2 brahches then 4 because A,B,C,D then 6 so at least 6 branches on last level. The 2D6 is the location.
This was a tree of all cytochrome across all species. Rabbits and mice have cytochromes but they have been eating different
things so their cytochrome diverged. animals arent useful to pharma because of PK the response of rat or other mammal
which diverged a long time ago does not have reliable pk resposne whereas for PD is good because the underlying biology is shared. 
primates are a little better but we diverged from apes milllions of years ago. PK is closer but as you go down evolutionary tree of life
gets further away. cheaper to experiment on other humans than apes. 
<img src="1232019_15.png">
back to codeine and CPK2D6 where the liver turns codeine into morphine. morphine works on about everybody but there
are mutations which cause morphine to be less effective. 
<img src="1232019_16.png">
7% of people of eurpoean descent got copy of 2D6 from mom and dad that is unable to do codeine->morphine reaction. 

<img src="1232019_17.png">
teh 7% are called poor metabolizers. There are others who are called ultrametabolizers: who have 2D6 which is extremely fast
    
<img src="1232019_18.png">
they have big spike, good for 15 minutes but then wears off. YOu can find poor metabolizer from SNPs can get from 23 adn me. 
Cant get ultrametabolizer from 23andme. 
ultrametabolier not about pain. woman who had baby was a nonmetabolizer. Couldnt make mortphone so she took lot of tylenol 3
teh baby had norlam copy of 2D6 from other parent and could metabolzie and in one case the baby died from morphone overdose. 
morphone depressed respiration. occured in North carolina, now in NC need to know 2D6 before taking. C2d6 metabolies 25% of all drugs
<img src="1232019_19.png">

# %%
for antidepresants 2d6 is inactiving them. so if you have different 2d6 and arent inactiving them normally then 
you will have too many sideeffects and stop taking drug. 
<img src="1232019_20.png">
summary: we did sequence analysis to find the variation in a pariwise and find family build tree. 3d structure to
    understand how to bind. 3d motif is binding pocket to figure out which AA matter. IF we dont have 3d motif we can
    predict it. We dont need super perfect informatoin on 3d stucture to get informaotin about binding pocket. 
    GWAS stucies associate drug response to SNP. networks because PD is often based on network of dat. Expression data: 
        we talked about drugs, how expression changes in cells. TMO informatics. opiods have high tanimoto similarity.

# %%
<img src="1232019_sup1.png">
<img src="1232019_sup2.png">
